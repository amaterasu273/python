# %%
print('hello')
# Out:
# hello

# %%
x = 5
y = 7
print(x, y)
# Out:
# 執行具有 'Python 3.11.2' 的儲存格需要 ipykernel 套件。
#
# 使用所需的套件<a href='command:jupyter.createPythonEnvAndSelectController'>建立 Python 環境</a>。

# %%
age=int(input("請輸入age"))

# %%
x = 5
y = 7
print(x, y)
# Out:
# 執行具有 'Python 3.11.2' 的儲存格需要 ipykernel 套件。
#
# 使用所需的套件<a href='command:jupyter.createPythonEnvAndSelectController'>建立 Python 環境</a>。

# %%
chinese=60
math=90
print("國文成績:"+str(chinese)+"數學成績:"+str(math))
print(f"國文成績:{chinese}")
# Out:
# 國文成績:60數學成績:90
# 國文成績:60
